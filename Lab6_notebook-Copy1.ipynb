# %%
# %matplotlib inline
from IPython.display import Image
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from decimal import Decimal
import scipy.optimize
import seaborn as sns
from IPython.display import Image
import math

# %% [markdown]
# [Insert Part 1 picture here]

# %% [markdown]
# Part 2: I build the circuit below. In reality, I am using 271 ohms instead of 270.

# %%
Image("LAB6-D1.png")

# %%
Image("LAB6-1.jpeg")

# %% [markdown]
# First I drive the circuit with a sine wave with amplitude of 3V. Afterwards, I attacked a -5V source to the bottom of the 3.3kOhm resistor using V-.

# %% [markdown]
# [Prediction here]

# %% [markdown]
# First graph scope below. Below that, is the graph of c1 vs c2. The slop of the line is the gain of the circuit. The gain is expected to be 1.

# %%
Image("LAB6-1.png")

# %%
Image("LAB6-2.png")

# %%
Image("LAB6-3.png")

# %% [markdown]
# Looking at the slope analysis, the slope is effectively 1. This means that the gain of the circuit is 1.

# %% [markdown]
# Below is the same ciruit but with -5V attached to the bottom of the 3.3K resistor. Below that is the +XY graph and below that is the slope analysis to find the gain.

# %%
Image("LAB6-4.png")

# %%
Image("LAB6-5.png")

# %%
Image("LAB6-6.png")

# %% [markdown]
# Once again, the amplification of the circuit is 1.
# ## [What use is there for this circuit?]

# %% [markdown]
# Now I need to try the same circuit with different resistors at the base. I am going to start at 33K resistance and increase it until I reach 50% attenuation. I used a resistor box for this process. The 50% attentuation point here, happens when the voltage at the BASE is half of the voltage input.

# %%
Image("LAB6-7.png")

# %% [markdown]
# This circuit was done using the 33k resistance instead of 270.

# %%
Image("LAB6-8.png")

# %% [markdown]
# Results with 50% attenuation. This was accomplished with 545Kohms.

# %% [markdown]
# [Estimate beta]

# %% [markdown]
# Next, I want to measure the output impedence. This starts by using the peak voltage of the default circuit, 2.381V(This is the V_thev). I then attach a 1K resistor in parallel with the 3.3K resistor. This represents a 1K load. I want to find the difference in peak voltage ouput.

# %%
Image("LAB6-9.png")

# %% [markdown]
# The new peak is at 2.322.
# ## [Calculate the Thevinins]

# %% [markdown]
# ## Part 3
#     This part involves creating the circuit below. I will measure the DC operating point. This can be done by measuring the voltage at the three terminals.
#     - 𝑉1 = 5 V, 𝑅1 = 20 kΩ, 𝑅2 = 10 kΩ, 𝑅𝐸 = 1 kΩ, and 𝑅𝐶 = 5 kΩ, and 10 μF capacitors

# %%
Image("LAB6-D2.png")

# %%
Image("LAB6-2.jpeg")

# %%
Image("LAB6-10.png")
## Voltage Output

# %%
Image("LAB6-11.png")
## Voltage at the collecter

# %%
Image("LAB6-12.png")
## Voltage at the Base

# %%
Image("LAB6-13.png")
## Voltage at the Emitter

# %% [markdown]
# [Insert voltage at the terminals and LT spice results]

# %%
Image("LAB6-VG.png")
## Voltage at the Base

# %%
Image("LAB6-VC.png")
## Voltage at the Collector

# %%
Image("LAB6-VE.png")
## Voltage at the Emitter

# %%
Image("LAB6-Vout.png")
## Voltage Output
